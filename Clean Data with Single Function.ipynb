# %%
import pandas as pd
import re
import numpy as np
pd.options.display.max_colwidth = 100

# %%
# 1. Step

def num_uniuni_1 (element):
    
    try:   
        t = re.findall(r"(\d+)\ ([a-z-A-Z]+\/[a-z-A-Z]+)", element) # pattern for; "100 Ui/Ml" to ----> 100 Ui/Ml----> 100 ml

        try:                      
            for item in t[0][1].split("/"):

                if item.lower()=="ml":
                    
                    element=element.replace(t[0][1],"ml")

                elif item=="G" or item=="M":
                    
                    element=element.replace(t[0][1],"mg")
        except:
        
            pass
    except:
        
        pass
    
    return element

# %%
# function test
num_uniuni_1 ("100 Ui/Ml XYZ 80Ml")
# Out:
# '100 ml XYZ 80Ml'

# %%
# 2. Step

def numuni_numuni_2(element):
    
    try:
        
        unit_list=["ML","Ml","mL","ml","MG","Mg","mG","mg","CM","Cm","cM","cm","M","Cps","L","G","Kg","KG","kg","G","GR","Gr"]
    
        list_element1= element.split(" ")
    
        for idx, item in enumerate(list_element1):
        
            z = re.match(r"([\d])+[a-zA-z]", item) # Pattern for; from ----> #300Ml/5ML  100Ml' to-----> [('300', 'Ml'), ('5', 'ML'), ('100', 'Ml')]
        
            if bool(z):
                          
                    zz=re.findall(r"(\d+)+([a-zA-Z]+)",item) # 300Ml/5ML  100Ml'-----> [('300', 'Ml'), ('5', 'ML'), ('100', 'Ml')]
                
                    del list_element1[idx]
                 
                    sep_elements = " ".join([element for tupl in zz for element in tupl])
                
                    list_element1.insert(idx,sep_elements.lower())   
                    
        element = " ".join(list_element1)
        
        return (element)    
    
    except:
        
        pass

# %%
# function test
numuni_numuni_2("A-Derma Dermalib Cr 50Mg/30Ml Abcd 50ML")
# Out:
# 'A-Derma Dermalib Cr 50 mg 30 ml Abcd 50 ml'

# %%
 # 3.Step
    
def num_uni_3(element):
    
    try:
        
        unit_list=["ML","Ml","mL","ml","MG","Mg","mG","mg","CM","Cm","cM","cm","M","Cps","L","G","Kg","KG","kg","G","GR","Gr","Mcg", "MCG"]
        
        list_element2= element.split(" ")
    
        # pattern for; from ---> 300 ML to ----> 300 ML-----> 300 ml
        # (previous pattern (to keep just in case) (r"(\d+)\ ([A-Z]+[a-z-A-Z])" ) 
        
        t = re.findall(r"(\d+)\ (\w+)", element)  
        
        for item in t:
        
            try:
            
                if item[1] in unit_list:
                
                    idx = list_element2.index(item[1])
                
                    del list_element2[idx]
                
                    list_element2.insert(idx,item[1].lower()) 
                
            except:
            
                pass  
            
        element = " ".join(list_element2) 
        
        return (element)
    
    except:
        
        pass

# %%
# function test
num_uni_3("Acarbose Bluepharma Mg, 100 Ml X 50 Comp")
# Out:
# 'Acarbose Bluepharma Mg, 100 ml X 50 Comp'

# %%
# 4.step 

def numnum_uni_4 (element):
    try:
        list_element= element.split(" ")
    
        t = re.findall(r"(\d+\/\d+)+([a-zA-Z]+)", element) # Pattern for; from ---> 50/150MG to ---> 50/150 mg
    
        try:
  
            for item in list_element:
        
                z = re.match(r"(\d+\/\d+)+([a-zA-Z]+)", item)
            
                if bool(z):
                
                    new_item = " ".join([x for tupl in t for x in tupl])
                
                    element = element.replace(item, new_item.lower() )

        except:
        
            pass
        
    except:
        
        pass
    
    return element

# %%
# function test
numnum_uni_4 ("50/150MG")
# Out:
# '50/150 mg'

# %%
# gathering all functions in a single function 
def allfunc(element):
    
    e1 = num_uniuni_1 (element)
    e2 = numuni_numuni_2(e1)
    e3 = num_uni_3(e2)
    e4 = numnum_uni_4 (e3)
    
    return e4

# %%
# function test
allfunc("Lauroderme Fraldas Tam 4 9-15 Kg X 50 Un")
# Out:
# 'Lauroderme Fraldas Tam 4 9-15 kg X 50 Un'

# %%
df=pd.read_excel("mapped_dataset.xlsx")

# %%
df["newly_cleaned_product_name"] = df["clean_product_name"].apply(allfunc)

# %%
df["newly_cleaned_product_name"].nunique()
# Out:
# 32913

# %%
df.sample(5)
# Out:
#                         file_name sheet_name      storesku  \
# 487822         ms_maculusso_11011  Maculusso  8.003671e+12
# 209075  kifarmacias_7pharm_110119  Lista KIL  8.766493e+06
# 164               fmarginal_15011     Sheet1  7.747683e+06
# 513872              kiluba_110119     Kiluba  8.144816e+06
# 517686             ms_hanga_11011      Hanga  6.939983e+06
#
#                                                product_name  store_id  \
# 487822      CHICCO PROTECTOR DE MAMILO SILICONE 2 PCS  0 M+      2045
# 209075   Fluocaril Bi-Fluoré 250, 2,5 mg/g x 125 pasta dent      2606
# 164                  Azul Metileno 1% Velvet Galenicos 30ml      2824
# 513872  Vibrocil, 0,25/2,5 mg/mL x 15 sol nasal conta-gotas      2128
# 517686                A-DERMA PHYS-AC GEL PURIFICANTE 200ML      3062
#
#                                    clean_name_list  \
# 487822                                          []
# 209075                 ['Fluocaril Bi-Fluore 250']
# 164                    ['Velvet Azul Metileno 1%']
# 513872                                ['Vibrocil']
# 517686  ['A-Derma Phys-Ac Gel Espuma Purificante']
#
#                                          clean_product_name       appy_id  \
# 487822      Chicco Protector De Mamilo Silicone 2 Pcs  0 M+            []
# 209075   Fluocaril Bi-Fluore 250, 2,5 Mg/G X 125 Pasta Dent        [2932]
# 164                  Azul Metileno 1% Velvet Galenicos 30Ml         [404]
# 513872  Vibrocil, 0,25/2,5 Mg/Ml X 15 Sol Nasal Conta-Gotas  [4519, 3195]
# 517686                A-Derma Phys-Ac Gel Purificante 200Ml        [1293]
#
#                               newly_cleaned_product_name
# 487822   Chicco Protector De Mamilo Silicone 2 Pcs  0 M+
# 209075  Fluocaril Bi-Fluore 250, 2,5 mg X 125 Pasta Dent
# 164              Azul Metileno 1% Velvet Galenicos 30 ml
# 513872  Vibrocil, 0,25/2,5 ml X 15 Sol Nasal Conta-Gotas
# 517686            A-Derma Phys-Ac Gel Purificante 200 ml

# %%
import numpy as np
df["recently_cleaned_product_name"]=np.where( (df['newly_cleaned_product_name']==df["clean_product_name"])
                                                        , np.nan, df['newly_cleaned_product_name'])

# %%
df.drop(columns=["newly_cleaned_product_name"], axis=1,inplace=True)

# %%
df.sample(50)
# Out:
#                         file_name      sheet_name      storesku  \
# 496951         palmeirinhas_10011    Palmeirinhas  1.069708e+06
# 515624             ms_hanga_11011           Hanga  4.393385e+06
# 509060         palmeirinhas_10011    Palmeirinhas  9.529214e+06
# 2003              fmarginal_15011         Vitória  9.981639e+06
# 500023         palmeirinhas_10011    Palmeirinhas  1.051391e+06
# 344154  kifarmacias_7pharm_110119       Lista ROP  4.147492e+06
# 276235  kifarmacias_7pharm_110119       Lista NOV  1.003863e+06
# 499640         palmeirinhas_10011    Palmeirinhas  5.109715e+06
# 517930             ms_hanga_11011           Hanga  7.898524e+12
# 140630  kifarmacias_7pharm_110119      Lista GIKA  1.007427e+06
# 510559        cuida_3pharm_110119  Cuida Talatona  2.050000e+12
# 501241         palmeirinhas_10011    Palmeirinhas  1.043307e+06
# 493455         ms_maculusso_20121       Maculusso  8.033892e+12
# 209472  kifarmacias_7pharm_110119       Lista KIL  7.343624e+06
# 494888         palmeirinhas_10011    Palmeirinhas  7.731984e+06
# 513378              kiluba_110119          Kiluba  1.037622e+06
# 411752  kifarmacias_7pharm_110119       Lista VIA  6.773739e+06
# 517510             ms_hanga_11011           Hanga  6.550707e+06
# 484851         ms_mixcenter_19121       Mixcenter  8.003671e+12
# 508321         palmeirinhas_10011    Palmeirinhas  6.830257e+06
# 489377       mosel_kilamba_120119         kilamba  9.524033e+06
# 768               fmarginal_15011          Sheet1  1.017558e+06
# 489550       mosel_kilamba_120119         kilamba  8.009518e+12
# 511416              kiluba_110119          Kiluba  5.440987e+06
# 484953         ms_mixcenter_19121       Mixcenter  6.209288e+06
# 756               fmarginal_15011          Sheet1  1.015123e+06
# 489487       mosel_kilamba_120119         kilamba  6.209759e+06
# 516416             ms_hanga_11011           Hanga  5.600745e+12
# 2254              fmarginal_15011         Vitória  9.356444e+06
# 73578   kifarmacias_7pharm_110119       Lista CAC  1.038703e+06
# 489289       mosel_kilamba_120119         kilamba  5.557509e+06
# 4996              fmarginal_15011         Vitória           NaN
# 508500         palmeirinhas_10011    Palmeirinhas  1.002022e+06
# 493834         palmeirinhas_10011    Palmeirinhas  1.083220e+06
# 507309         palmeirinhas_10011    Palmeirinhas  1.007922e+06
# 516640             ms_hanga_11011           Hanga  3.518646e+12
# 513188              kiluba_110119          Kiluba  7.392852e+06
# 276386  kifarmacias_7pharm_110119       Lista NOV  9.385211e+06
# 496959         palmeirinhas_10011    Palmeirinhas  1.069674e+06
# 5005              fmarginal_15011         Vitória  6.001076e+12
# 515672             ms_hanga_11011           Hanga  5.384375e+06
# 493834         Pantoprazol Labesfal 20mg 1LAM 7cp cx56 Pantoc      3117
# 507309               Tommee explora tigela plast 4m+ ref:7027      3117
# 516640                               PARASIDOSE 100ML SOLUÇÃO      3062
# 513188              Nutriben Natal Ar Leite Regurg Lact 800 G      2128
# 276386               Imodium, 0,2 mg/mL x 100 sol oral medida      2500
# 496959                     Levitra 10mg 1CAIXA 4cp Vardenafil      3117
# 5005                         AQUAFRESH ESCOVE DE DENTES HARD.      2824
# 515672  CANDESARTAN+HIDROCLOROTIAZIDA 16MG+12,5MG LAM 14 COMP      3062
# 509332                                          Augmentin Duo      3117
# 73941              Synalar N, 0,025/0,35 %p/p x 40 creme bisn      2252
# 511088                            DIORALYTE LIMAO 20 SAQUETAS      3365
# 503987               Tramal 50mg 1LAM 10cp cx20 Tramadol 50mg      3117
# 221                                Ben-U-Ron, 250 mg x 10 sup      2824
# 2903                               DERMOFLAN FLUIDO EMOLIENTE      2824
# 3757            CORINE DE FARME SHAMPO 2EM1 SPIDER MAN-250ML.      2824
# 504544                                 Punho munequera velcro      3117
# 5977                                     Nutrisaúde ZMAS Comp      2641
#
#                                            clean_name_list  \
# 496951                                                  []
# 515624                                   ['Tram-U-Ron Od']
# 509060                                                  []
# 2003                                                    []
# 500023                                                  []
# 344154                                          ['Clinac']
# 276235                           ['Co-Arinate Adulto Fdc']
# 499640                                                  []
# 517930                                                  []
# 140630                                                  []
# 510559                                                  []
# 501241                                                  []
# 493455                                                  []
# 209472  ['Nutriben Boiao Maca, Laranja, Banana E Bolacha']
# 494888                                                  []
# 513378                                                  []
# 411752                               ['Elgydium Creation']
# 517510                   ['Klorane Dermo Pro Creme Maos ']
# 484851                                                  []
# 508321                     ['Elancyl Serum Firmeza Busto']
# 489377                                        ['Baycuten']
# 768                                                     []
# 489550                                                  []
# 511416                                   ['Ben-U-Ron Cmp']
# 484953                                                  []
# 756                   ['Hassemed Luva Latex C/Po S X 100']
# 489487             ['Cinta Contencao Abdominal 3 Faixas ']
# 516416                                                  []
# 2254                                                    []
# 73578                               ["L'Enfance Sabonete"]
# 489289                                         ['Aero-Om']
# 4996                                                    []
# 508500                                                  []
# 493834                                                  []
# 507309            ['Chicco Brinquedo Bateria Musical 9M+']
# 516640                                                  []
# 513188       ['Nutriben Natal Ar Leite Anti-Regurgitacao']
# 276386                                         ['Imodium']
# 496959                                                  []
# 5005                                                    []
# 515672      ['Candesartan + Hidroclorotiazida Bluepharma']
# 509332                                                  []
# 73941                                        ['Synalar N']
# 511088                         ['Dioralyte (Sabor Limao)']
# 503987                                                  []
# 221                                      ['Ben-U-Ron Sup']
# 2903                                                    []
# 3757                                                    []
# 504544  ['Coloracao Excellence Creme  Castanho Claro 5.0']
# 5977                                                    []
#
#                                            clean_product_name appy_id  \
# 511088                            Dioralyte Limao 20 Saquetas   [630]
# 503987               Tramal 50Mg 1Lam 10Cp Cx20 Tramadol 50Mg      []
# 221                                Ben-U-Ron, 250 Mg X 10 Sup   [431]
# 2903                               Dermoflan Fluido Emoliente      []
# 3757            Corine De Farme Shampo 2Em1 Spider Man-250Ml.      []
# 504544                                 Punho Munequera Velcro  [4595]
# 5977                                     Nutrisaude Zmas Comp      []
#
#                                 recently_cleaned_product_name
# 496951       Mucoral Adul 50 mg Xar=Carbocis,Fluditec Adul 5%
# 515624  Tram-U-Ron Od(Cloridrato De Tramal) 150 mg Cx 20 Comp
# 509060                                                    NaN
# 2003               Lopresor 200 mg (Metoprolol.) - Blt. 10 Cp
# 500023               Acabel 8 8 mg 15 ml Inj 1 amp Lornoxicam
# 344154                            Clinac, 20 ml X 100 Sol Cut
# 276235                 Co-Arinate Adulto Fdc 200 Mg+500+25 mg
# 499640                                                    NaN
# 517930          Salon Line Shampoo Trat Coco Todecacho 300 ml
# 140630                        Amifer 30 Mg/5 ml 200 ml Xarope
# 510559                    Amidol Shalina 120 mg 5 ml 60 ml Xp
# 501241                                                    NaN
# 493455                                                    NaN
# 209472              Nutriben Boiao Boiao 1 Mac La Ba Bo 130 g
# 494888                   Agua Oxigenada Ag Ox 10 v 250 ml Aga
# 513378           Pravastatina Generis Mg, 20 mg X Blt 10 Comp
# 411752                                                    NaN
# 517510                            Klorane Creme De Maos 50 ml
# 484851                                                    NaN
# 508321                                                    NaN
# 489377                                       Baycuten Cr 30 g
# 768                  + Hidroclorotiazida 25 mg 60 comprimidos
# 489550                                                    NaN
# 511416                           Ben-U-Ron, 1000 mg X 18 Comp
# 484953                                                    NaN
# 756                                                       NaN
# 489487                                                    NaN
# 516416                                                    NaN
# 2254                 Neufil 500 mg (Diprofilina) - Blt. 10 Cp
# 73578                         L Enfance Sabonete Solido 90 gr
# 489289                               Aeron Om Gts Orais 25 ml
# 4996                                                      NaN
# 508500                                                    NaN
# 493834      Pantoprazol Labesfal 20 mg 1 lam 7 cp Cx56 Pantoc
# 507309               Tommee Explora Tigela Plast 4 m Ref:7027
# 516640                              Parasidose 100 ml Solucao
# 513188              Nutriben Natal Ar Leite Regurg Lact 800 g
# 276386                  Imodium, 0,2 ml X 100 Sol Oral Medida
# 496959                  Levitra 10 mg 1 caixa 4 cp Vardenafil
# 5005                                                      NaN
# 515672   Candesartan+Hidroclorotiazida 16 mg 5 mg Lam 14 Comp
# 509332                                                    NaN
# 73941                                                     NaN
# 511088                                                    NaN
# 503987           Tramal 50 mg 1 lam 10 cp Cx20 Tramadol 50 mg
# 221                                Ben-U-Ron, 250 mg X 10 Sup
# 2903                                                      NaN
# 3757            Corine De Farme Shampo 2 em Spider Man-250Ml.
# 504544                                                    NaN
# 5977                                                      NaN

# %%
df.to_csv("cleaned_dataset.csv")
